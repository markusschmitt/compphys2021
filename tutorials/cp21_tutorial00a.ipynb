# %% [markdown]
# # Computerphysik Programmiertutorial 0 (Erste Schritte)
# Prof. Dr. Matteo Rizzi und Dr. Markus Schmitt - Institut für Theoretische Physik, Universität zu Köln
# &nbsp;
#
# **Github**: [https://github.com/markusschmitt/compphys2021](https://github.com/markusschmitt/compphys2021)
#
# **Inhalt dieses Notebooks**: Jupyter notebook bedienen, Installation der benötigten Pakete

# %% [markdown]
# ## Jupyter notebooks bedienen

# %% [markdown]
# `CTRL` = `STRG` = "Steuerungstaste" (Achtung: Auf Mac = `COMMAND`)
#
# `SHIFT` = "Umschalttaste"
#
# * `CTRL` + `ENTER` = Zelle ausführen
# * `SHIFT` + `ENTER` = Zelle ausführen und zur nächsten Zelle springen.
# * `ESC` danach `B` = Neue Zelle nach aktueller Zelle
# * `ESC` danach `A` = Neue Zelle vor aktueller Zelle
# * `ESC` danach `X` = Aktuelle Zelle löschen
#
# Tipp: `STRG + SHIFT + P`

# %% [markdown]
# Ein Semikolon `;` am Ende einer Zelle unterdrückt die automatische Ausgabe.

# %% [markdown]
# ## Installation der benötigten Pakete

# %% [markdown]
# Durch Ausführen der nächsten beiden Zellen wird erst ein Installationsskript von unserem Computerphysik-Repository heruntergeladen, mit dem anschließend sehr einfach alle für die Programmiertutorials und für die Übungen benötigten Julia-Pakete installiert werden.

# %%
# Herunterladen und einbinden eines kleinen Helferskripts
#download("https://raw.githubusercontent.com/markusschmitt/compphys2021/main/tutorials/install.jl", "install1.jl")
include("install1.jl")

# %% [markdown]
# Der folgende Befehl kann eine (ganze) Weile dauern. Erst wenn links in den eckigen Klammern **nach dem Ausführen** wieder eine Zahl (und kein `*`) mehr steht ist die Installation abgeschlossen.

# %%
install_overwrite()
# Out:
# ┌ Info: Installiere IJulia
# └ @ Main /Users/markus/Teaching/Computerphysik/2020/compphys2021/tutorials/install1.jl:68
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [7073ff75] + IJulia v1.23.2
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [8f4d0f93] + Conda v1.5.1
#   [7073ff75] + IJulia v1.23.2
#   [692b3bcd] + JLLWrappers v1.2.0
#   [682c06a0] + JSON v0.21.1
#   [739be429] + MbedTLS v1.0.3
#   [69de0a69] + Parsers v1.1.0
#   [b85f4697] + SoftGlobalScope v1.1.0
#   [81def892] + VersionParsing v1.2.0
#   [c2297ded] + ZMQ v1.2.1
#   [8f1865be] + ZeroMQ_jll v4.3.2+6
#   [a9144af2] + libsodium_jll v1.0.19+0
#   [0dad84c5] + ArgTools
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads
#   [7b1f6079] + FileWatching
#   [b77e0a4c] + InteractiveUtils
#   [b27032c2] + LibCURL
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions
#   [44cfe95a] + Pkg
#   [de0858da] + Printf
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA
#   [9e88b42a] + Serialization
#   [6462fe0b] + Sockets
#   [fa267f1f] + TOML
#   [a4e569a6] + Tar
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [deac9b47] + LibCURL_jll
#   [29816b5a] + LibSSH2_jll
#   [c8ffd9c3] + MbedTLS_jll
#   [14a3606d] + MozillaCACerts_jll
#   [83775a58] + Zlib_jll
#   [8e850ede] + nghttp2_jll
#   [3f19e933] + p7zip_jll
# ┌ Info: Installiere alle Pakete...
# └ @ Main /Users/markus/Teaching/Computerphysik/2020/compphys2021/tutorials/install1.jl:72
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [6e4b80f9] + BenchmarkTools v0.7.0
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [6e4b80f9] + BenchmarkTools v0.7.0
#   [37e2e46d] + LinearAlgebra
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#    Resolving package versions...
#    Installed TableTraits ─ v1.0.1
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [336ed68f] + CSV v0.8.4
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [336ed68f] + CSV v0.8.4
#   [9a962f9c] + DataAPI v1.6.0
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [2dfb63ee] + PooledArrays v1.2.1
#   [91c51154] + SentinelArrays v1.2.16
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.4.1
#   [9fa8497b] + Future
# Precompiling project...
#   ✓ TableTraits
#   ✓ Tables
#   ✓ CSV
# 3 dependencies successfully precompiled in 6 seconds (20 already precompiled)
#    Resolving package versions...
#    Installed ChainRulesCore ─ v0.9.36
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [5d742f6a] + CSVFiles v1.0.0
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [b99e7846] + BinaryProvider v0.5.10
#   [5d742f6a] + CSVFiles v1.0.0
#   [d360d2e6] + ChainRulesCore v0.9.36
#   [944b1d66] + CodecZlib v0.6.0
#   [34da2185] + Compat v3.25.0
#   [864edb3b] + DataStructures v0.18.9
#   [e7dc6d0d] + DataValues v0.4.13
#   [497a8b3b] + DoubleFloats v1.1.18
#   [e2ba6199] + ExprTools v0.1.3
#   [8f5d6c58] + EzXML v1.1.0
#   [5789e2e9] + FileIO v1.6.5
#   [01680d73] + GenericSVD v0.3.0
#   [c145ed77] + GenericSchur v0.5.0
#   [cd3eb016] + HTTP v0.8.19
#   [83e8ac13] + IniFile v0.5.0
#   [d8418881] + Intervals v1.5.0
#   [1c8ee90f] + IterableTables v1.0.0
#   [e1d29d7a] + Missings v0.4.5
#   [78c3b35d] + Mocking v0.7.1
#   [4d1e1d77] + Nullables v1.0.0
#   [bac558e1] + OrderedCollections v1.4.0
#   [f27b6e38] + Polynomials v2.0.5
#   [be4d8f0f] + Quadmath v0.5.5
#   [3cdcf5f2] + RecipesBase v1.1.1
#   [ae029012] + Requires v1.1.3
#   [276daf66] + SpecialFunctions v1.3.0
#   [5e66a065] + TableShowUtils v0.2.5
#   [382cd787] + TableTraitsUtils v1.0.1
#   [e0df1984] + TextParse v1.0.1
#   [f269a46b] + TimeZones v1.5.3
#   [3bb67fe8] + TranscodingStreams v0.9.5
#   [ea10d353] + WeakRefStrings v0.6.2
#   [94ce4f54] + Libiconv_jll v1.16.0+7
#   [efe28fd5] + OpenSpecFun_jll v0.5.3+4
#   [02c8fc9c] + XML2_jll v2.9.11+0
#   [8bb1440f] + DelimitedFiles
#   [8ba89e20] + Distributed
#   [1a1011a3] + SharedArrays
#   [e66e0078] + CompilerSupportLibraries_jll
# Precompiling project...
#   ✓ ChainRulesCore
#   ✓ SpecialFunctions
#   ✓ DoubleFloats
#   ✓ TextParse
#   ✓ CSVFiles
# 5 dependencies successfully precompiled in 11 seconds (54 already precompiled)
#    Resolving package versions...
#    Installed FixedPointNumbers ─ v0.7.1
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [3da002f7] + ColorTypes v0.8.1
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [3da002f7] + ColorTypes v0.8.1
#   [53c48c17] + FixedPointNumbers v0.7.1
# Precompiling project...
#   ✓ FixedPointNumbers
#   ✓ ColorTypes
# 2 dependencies successfully precompiled in 5 seconds (59 already precompiled)
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [667455a9] + Cubature v1.5.1
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [667455a9] + Cubature v1.5.1
#   [7bc98958] + Cubature_jll v1.0.4+0
#    Resolving package versions...
#    Installed Reexport ─ v1.0.0
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [a93c6f00] + DataFrames v0.22.7
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [324d7699] + CategoricalArrays v0.9.4
#   [a8cc5b0e] + Crayons v4.0.4
#   [a93c6f00] + DataFrames v0.22.7
#   [59287772] + Formatting v0.4.2
#   [41ab1584] + InvertedIndices v1.0.0
#   [08abe8d2] + PrettyTables v0.11.1
#   [189a3867] + Reexport v1.0.0
#   [a2af1166] + SortingAlgorithms v0.3.1
#   [856f2bd8] + StructTypes v1.5.0
# Precompiling project...
#   ✓ Reexport
#   ✓ PrettyTables
#   ✓ DataFrames
# 3 dependencies successfully precompiled in 23 seconds (69 already precompiled)
#    Resolving package versions...
#    Installed Latexify ─────────────── v0.15.0
#    Installed OffsetArrays ─────────── v1.6.2
#    Installed RecursiveFactorization ─ v0.1.11
#    Installed SteadyStateDiffEq ────── v1.6.2
#    Installed Adapt ────────────────── v3.2.0
#    Installed ThreadingUtilities ───── v0.2.5
#    Installed SLEEFPirates ─────────── v0.6.10
#    Installed Symbolics ────────────── v0.1.13
#    Installed VectorizationBase ────── v0.18.14
#    Installed LoopVectorization ────── v0.11.2
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [0c46a032] + DifferentialEquations v6.16.0
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [c3fe647b] + AbstractAlgebra v0.15.1
#   [1520ce14] + AbstractTrees v0.3.4
#   [79e6a3ab] + Adapt v3.2.0
#   [ec485272] + ArnoldiMethod v0.1.0
#   [4fba245c] + ArrayInterface v3.1.6
#   [4c555306] + ArrayLayouts v0.6.4
#   [aae01518] + BandedMatrices v0.16.8
#   [764a87c0] + BoundaryValueDiffEq v2.7.1
#   [fa961155] + CEnum v0.4.1
#   [861a8166] + Combinatorics v1.0.2
#   [38540f10] + CommonSolve v0.2.0
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [187b0558] + ConstructionBase v1.1.0
#   [bcd4f6db] + DelayDiffEq v5.29.1
#   [2b5f629d] + DiffEqBase v6.58.0
#   [459566f4] + DiffEqCallbacks v2.16.1
#   [5a0ffddc] + DiffEqFinancial v2.4.0
#   [c894b116] + DiffEqJump v6.13.0
#   [77a26b50] + DiffEqNoiseProcess v5.7.1
#   [055956cb] + DiffEqPhysics v3.9.0
#   [163ba53b] + DiffResults v1.0.3
#   [b552c78f] + DiffRules v1.0.2
#   [0c46a032] + DifferentialEquations v6.16.0
#   [c619ae07] + DimensionalPlotRecipes v1.2.0
#   [b4f34e82] + Distances v0.10.2
#   [31c24e10] + Distributions v0.24.15
#   [ffbed154] + DocStringExtensions v0.8.4
#   [d4d017d3] + ExponentialUtilities v1.8.1
#   [9aa1b823] + FastClosures v0.3.2
#   [1a297f60] + FillArrays v0.11.7
#   [6a86dc24] + FiniteDiff v2.8.0
#   [f6369f11] + ForwardDiff v0.10.17
#   [069b7b12] + FunctionWrappers v1.1.2
#   [0e44f5e4] + Hwloc v1.3.0
#   [615f187c] + IfElse v0.1.0
#   [d25df0c9] + Inflate v0.1.2
#   [42fd0dbc] + IterativeSolvers v0.9.0
#   [b964fa9f] + LaTeXStrings v1.2.1
#   [2ee39098] + LabelledArrays v1.6.0
#   [23fbe1c1] + Latexify v0.15.0
#   [093fc24a] + LightGraphs v1.3.5
#   [d3d80556] + LineSearches v7.1.1
#   [bdcacae8] + LoopVectorization v0.11.2
#   [1914dd2f] + MacroTools v0.5.6
#   [961ee093] + ModelingToolkit v5.14.0
#   [46d2c3a1] + MuladdMacro v0.2.2
#   [f9640e96] + MultiScaleArrays v1.8.1
#   [d41bc354] + NLSolversBase v7.8.0
#   [2774e3e8] + NLsolve v4.5.1
#   [77ba4419] + NaNMath v0.3.5
#   [8913a72c] + NonlinearSolve v0.3.8
#   [6fe1bfb0] + OffsetArrays v1.6.2
#   [429524aa] + Optim v1.3.0
#   [1dea7af3] + OrdinaryDiffEq v5.52.2
#   [90014a1f] + PDMats v0.11.0
#   [65888b18] + ParameterizedFunctions v5.10.0
#   [d96e819e] + Parameters v0.12.2
#   [e409e4f3] + PoissonRandom v0.4.0
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [1fd47b50] + QuadGK v2.4.1
#   [74087812] + Random123 v1.3.1
#   [fb686558] + RandomExtensions v0.4.3
#   [e6cf234a] + RandomNumbers v1.4.0
#   [731186ca] + RecursiveArrayTools v2.11.0
#   [f2c3362d] + RecursiveFactorization v0.1.11
#   [ae5879a3] + ResettableStacks v1.1.0
#   [79098fc4] + Rmath v0.7.0
#   [7e49a35a] + RuntimeGeneratedFunctions v0.5.1
#   [476501e8] + SLEEFPirates v0.6.10
#   [1bc83da4] + SafeTestsets v0.0.1
#   [0bca4576] + SciMLBase v1.10.0
#   [efcf1570] + Setfield v0.7.0
#   [699a6c99] + SimpleTraits v0.9.3
#   [47a9eef4] + SparseDiffTools v1.13.0
#   [aedffcd0] + Static v0.2.4
#   [90137ffa] + StaticArrays v1.1.0
#   [2913bbd2] + StatsBase v0.33.4
#   [4c63d2b9] + StatsFuns v0.9.7
#   [9672c7b4] + SteadyStateDiffEq v1.6.2
#   [789caeaf] + StochasticDiffEq v6.33.1
#   [c3572dad] + Sundials v4.4.1
#   [d1185830] + SymbolicUtils v0.9.4
#   [0c5d862f] + Symbolics v0.1.13
#   [8290d209] + ThreadingUtilities v0.2.5
#   [a759f4b9] + TimerOutputs v0.5.8
#   [a2a6695c] + TreeViews v0.3.0
#   [3a884ed6] + UnPack v1.0.2
#   [1986cc42] + Unitful v1.6.0
#   [3d5dd08c] + VectorizationBase v0.18.14
#   [19fa3120] + VertexSafeGraphs v0.1.2
#   [700de1a5] + ZygoteRules v0.2.1
#   [e33a78d0] + Hwloc_jll v2.4.1+0
#   [f50d1b31] + Rmath_jll v0.3.0+0
#   [fb77eaff] + Sundials_jll v5.2.0+1
#   [4607b0f0] + SuiteSparse
#   [4536629a] + OpenBLAS_jll
#   [bea87d4a] + SuiteSparse_jll
# Precompiling project...
#   ✓ Adapt
#   ✓ AbstractTrees
#   ✓ ArrayInterface
#   ✓ OffsetArrays
#   ✓ Latexify
#   ✓ FiniteDiff
#   ✓ LabelledArrays
#   ✓ RecursiveArrayTools
#   ✓ VectorizationBase
#   ✓ AbstractAlgebra
#   ✓ ThreadingUtilities
#   ✓ SLEEFPirates
#   ✓ SciMLBase
#   ✓ NLSolversBase
#   ✓ SparseDiffTools
#   ✓ LineSearches
#   ✓ NLsolve
#   ✓ LoopVectorization
#   ✓ Optim
#   ✓ RecursiveFactorization
#   ✓ SymbolicUtils
#   ✓ NonlinearSolve
#   ✓ DiffEqBase
#   ✓ DiffEqJump
#   ✓ BoundaryValueDiffEq
#   ✓ Sundials
#   ✓ Symbolics
#   ✓ DiffEqNoiseProcess

# %% [markdown]
# > **Hinweis:** Sollte es mit dem Befehl `install()` zu Problemen kommen, kann `install_overwrite()` verwendet werden. Letzteres **überschreibt(!)** die vorhandene Julia-Umgebung, d.h. bereits installierte Pakete gehen verloren.
